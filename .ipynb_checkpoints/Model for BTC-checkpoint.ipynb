# %% [markdown]
# # Modeling BTC

# %% [markdown]
# ## Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import itertools
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
from tqdm import tqdm_notebook as tqdm
import _pickle as pickle
plt.style.use('ggplot')

# %% [markdown]
# ## Loading in and formatting the Data

# %%
bc = pd.read_csv('BTC-USD.csv')
bc.head()
# Out:
#          Date     Open     High      Low    Close  Adj Close  Volume
# 0  2010-07-17  0.04951  0.04951  0.04951  0.04951    0.04951       0
# 1  2010-07-18  0.04951  0.08585  0.05941  0.08584    0.08584       5
# 2  2010-07-19  0.08584  0.09307  0.07723  0.08080    0.08080      49
# 3  2010-07-20  0.08080  0.08181  0.07426  0.07474    0.07474      20
# 4  2010-07-21  0.07474  0.07921  0.06634  0.07921    0.07921      42

# %% [markdown]
# ### Converting Dates into a Datetime Format

# %%
bc['Date'] = pd.to_datetime(bc.Date)
bc.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %% [markdown]
# #### Setting dates as the index

# %%
bc.set_index('Date', inplace=True)
bc.head()
# Out:
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 2010-07-17  0.04951  0.04951  0.04951  0.04951    0.04951       0
# 2010-07-18  0.04951  0.08585  0.05941  0.08584    0.08584       5
# 2010-07-19  0.08584  0.09307  0.07723  0.08080    0.08080      49
# 2010-07-20  0.08080  0.08181  0.07426  0.07474    0.07474      20
# 2010-07-21  0.07474  0.07921  0.06634  0.07921    0.07921      42

# %% [markdown]
# #### Selecting only the Closing Price as well as the dates starting from January 2017.
# This is the time when Bitcoin and Cryptocurrency in general started to become popular to trade.

# %%
bc = bc[['Close']].loc['2017-01-01':]
bc.head()
# Out:
#                   Close
# Date
# 2017-01-01   995.440002
# 2017-01-02  1017.049988
# 2017-01-03  1033.300049
# 2017-01-04  1135.410034
# 2017-01-05   989.349976

# %% [markdown]
# ### Exporting this data for later use

# %%
with open("curr_bitcoin.pickle", 'wb') as fp:
    pickle.dump(bc, fp)

# %% [markdown]
# ## Plotting and EDA

# %%
bc.plot(figsize=(12,5))

plt.xlabel('Date')
plt.ylabel('Price in USD')
plt.title('BTC Price')
plt.show()

# %%
bc.describe()
# Out:
#               Close
# count    983.000000
# mean    6078.625359
# std     3613.300566
# min      785.429993
# 25%     3558.160034
# 50%     6209.470215
# 75%     8235.060059
# max    19345.490234

# %% [markdown]
# ## Detrending

# %% [markdown]
# ### Method #1 - Differencing the Data

# %%
bc_diff = bc.diff().dropna()
bc_diff.plot(figsize=(12,5))
plt.title('Plot of the Daily Changes in Price for BTC')
plt.ylabel('Change in USD')
plt.show()

# %% [markdown]
# #### Testing for Stationarity

# %%
results = adfuller(bc_diff.Close)
print(f"P-value: {results[1]}")
# Out:
# P-value: 1.0705745337703831e-07

# %% [markdown]
# ### Method #2 - Taking the Log, rolling mean, then differencing them

# %%
bc_log = pd.DataFrame(np.log(bc.Close))
rol_mean = bc_log.rolling(7).mean().dropna()

# %%
plt.figure(figsize=(16,8))
plt.plot(bc_log, label='Log')
plt.plot(rol_mean, label='Rolling Mean')
plt.title('Log and Rolling Mean of BTC')
plt.xlabel('Dates')
plt.legend()
plt.show()

# %%
log_mean_diff = (bc_log - rol_mean).dropna()

# %%
plt.figure(figsize=(16,8))
plt.plot(log_mean_diff)
plt.title('Daily Difference between Log and Rolling Mean')
plt.show()

# %% [markdown]
# #### Testing for Stationarity

# %%
results = adfuller(log_mean_diff.Close)
print(f"P-value: {results[1]}")
# Out:
# P-value: 2.830093353279159e-14

# %% [markdown]
# ## PACF and ACF

# %% [markdown]
# #### ACF and PACF for the Differencing

# %%
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(16,8))
plot_acf(bc_diff, ax=ax1, lags=40)
plot_pacf(bc_diff, ax=ax2, lags=40)
plt.show()

# %% [markdown]
# Not much correlation, if none at all, between the current price and the prices from N days ago.

# %% [markdown]
# #### ACF and PACF for the Log and Mean Difference

# %%
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(16,8))
plot_acf(log_mean_diff, ax=ax1, lags=40)
plot_pacf(log_mean_diff, ax=ax2, lags=40)
plt.show()

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## ARIMA Model for Differencing

# %% [markdown]
# ### Finding the Best Parameters for ARIMA

# %%
def best_param(model, data, pdq, pdqs):
    ans = []
    for comb in tqdm(pdq):
        for combs in pdqs:
            try:
                mod = model(data,
                            order=comb,
                            seasonal_order=combs,
                            enforce_stationarity=False,
                            enforce_invertibility=False,
                            freq='D')

                output = mod.fit()
                ans.append([comb, combs, output.aic])
                #print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
            except:
                continue
           
    ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
    return ans_df.loc[ans_df.aic.idxmin()]

# %%
p = d = q = range(0,3)
d = [2]
pdq = list(itertools.product(p, d, q))

#pdqs = [(i[0],i[1],i[2],12) for i in pdq]
pdqs = [(2,1,2,52)]

# %%
#best_param(SARIMAX, bc, pdq, pdqs)

# %% [markdown]
# #### Best Parameters according to the function

# %%
# pdq         (0, 2, 2)
# pdqs    (2, 1, 2, 52)
# aic           12281.5

# %% [markdown]
# ### Fitting and Training SARIMAX

# %%
model = SARIMAX(bc, 
                order=(0, 2, 2), 
                seasonal_order=(2,1,2,52), 
                freq='D', 
                enforce_stationarity=False, 
                enforce_invertibility=False)
output = model.fit()
# Out:
# /anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# /anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %% [markdown]
# Fitting the model with weekly seasonality consumes plenty of processing power.  Time to finish is usually 5 minutes for fitting just one model.

# %%
print(output.summary())
output.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                              Close   No. Observations:                  983
# Model:             SARIMAX(0, 2, 2)x(2, 1, 2, 52)   Log Likelihood               -6133.746
# Date:                            Mon, 23 Sep 2019   AIC                          12281.491
# Time:                                    19:42:10   BIC                          12314.474
# Sample:                                01-01-2017   HQIC                         12294.145
#                                      - 09-10-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.9665      0.019    -49.620      0.000      -1.005      -0.928
# ma.L2         -0.0294      0.020     -1.506      0.132      -0.068       0.009
# ar.S.L52      -0.5636      0.595     -0.947      0.344      -1.730       0.603
# ar.S.L104     -0.0155      0.046     -0.339      0.735      -0.105       0.074
# ma.S.L52      -0.4932      0.601     -0.821      0.412      -1.671       0.685
# ma.S.L104     -0.5070      0.612     -0.829      0.407      -1.706       0.692
# sigma2      1.571e+05   1.88e-06   8.34e+10      0.000    1.57e+05    1.57e+05
# ===================================================================================
# Ljung-Box (Q):                      103.29   Jarque-Bera (JB):              2148.07
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.40   Skew:                            -0.14
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.47e+27. Standard errors may be unstable.

# %% [markdown]
# ### Predictions with ARIMA

# %%
predictions = output.get_prediction(start=pd.to_datetime('2019-08-01'), dynamic=False)
conf_int = predictions.conf_int()

# %%
rcParams['figure.figsize'] = 16, 8

ax = bc['2019-06-01':].plot(label='Actual Price')

# Plotting predictions
predictions.predicted_mean.plot(label='Predictions')

# Confidence interval
ax.fill_between(conf_int.index, conf_int.iloc[:,0], conf_int.iloc[:,1], color='g',alpha=.5)

plt.legend()
plt.show()

# %%
forecast = predictions.predicted_mean
actual_val = bc['2019-08-01':].Close

# Calculating our errors
rmse = np.sqrt(((forecast - actual_val) ** 2).mean())

print("The Root Mean Squared Error: ", rmse)
# Out:
# The Root Mean Squared Error:  340.3648782433403

# %% [markdown]
# ### Forecasting Future Values

# %%
# Getting the forecast of future values
future = output.get_forecast(steps=30)
# Confidence interval for our forecasted values
pred_conf = future.conf_int()
# Out:
# /anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)

# %% [markdown]
# #### Plotting the forecasted values

# %%
ax = bc['2019-06-01':].plot(label='Actual', figsize=(16,8))
future.predicted_mean.plot(ax=ax, label='Future Vals')

ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='k', alpha=.25)

ax.set_xlabel('Date')
ax.set_ylabel('Bitcoin Price')
#ax.set_ylim([9000,11000])

plt.title('Forecasted values')
plt.legend()
plt.show()

# %%
# Graph zoomed in

ax = bc['2019-06-01':].plot(label='Actual', figsize=(16,8))
future.predicted_mean.plot(ax=ax, label='Future Vals')

ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='k', alpha=.25)

ax.set_xlabel('Date')
ax.set_ylabel('Bitcoin Price')
ax.set_ylim([9000,12000])

plt.title('Forecasted values')
plt.legend()
plt.show()
