# %% [markdown]
# # BTC - Facebook Prophet

# %% [markdown]
# ### Importing libraries

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# %matplotlib inline
from matplotlib.pylab import rcParams
plt.style.use('ggplot')
import _pickle as pickle

from fbprophet import Prophet as proph

# %% [markdown]
# ### Loading in the Data

# %%
with open("curr_bitcoin.pickle",'rb') as fp:
    ts = pickle.load(fp)

# %% [markdown]
# ### Formatting the data for Facebook Prophet

# %%
# Resetting the index back so Dates are no longer indexed
ts.reset_index(inplace=True)

# Renaming the columns for use in FB prophet
ts.rename(columns={'Date': 'ds', 'Close': 'y'}, inplace=True)

ts.head()
# Out:
#           ds            y
# 0 2017-01-01   995.440002
# 1 2017-01-02  1017.049988
# 2 2017-01-03  1033.300049
# 3 2017-01-04  1135.410034
# 4 2017-01-05   989.349976

# %% [markdown]
# #### Plotting

# %%
# Plotting the price movement
pd.plotting.register_matplotlib_converters()

ax = ts.set_index('ds').plot(figsize=(16,8))
ax.set_ylabel('Bitcoin Price')
ax.set_xlabel('Date')

plt.show()

# %% [markdown]
# ### Modeling

# %%
mod = proph(interval_width=0.95)
mod.fit(ts)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# #### Creating future dates to forecast

# %%
future = mod.make_future_dataframe(periods=30, freq='D')
future.tail()
# Out:
#              ds
# 1008 2019-10-06
# 1009 2019-10-07
# 1010 2019-10-08
# 1011 2019-10-09
# 1012 2019-10-10

# %% [markdown]
# #### Forecasting future values

# %%
forecast = mod.predict(future)
forecast.tail()
# Out:
#              ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 1008 2019-10-06  13953.914541  11370.261169  15575.630533  13605.918256
# 1009 2019-10-07  13998.000240  11246.156118  15661.384432  13635.246020
# 1010 2019-10-08  14042.085938  11277.298233  15559.689798  13662.526607
# 1011 2019-10-09  14086.171637  11398.165303  15759.200609  13675.851273
# 1012 2019-10-10  14130.257335  11264.592129  15771.006624  13700.923208
#
#        trend_upper  additive_terms  additive_terms_lower  \
# 1008  14278.688653     -533.175053           -533.175053
# 1009  14345.026779     -495.907742           -495.907742
# 1010  14411.428764     -505.261890           -505.261890
# 1011  14477.811677     -478.771154           -478.771154
# 1012  14542.766082     -479.411834           -479.411834
#
#       additive_terms_upper     weekly  weekly_lower  weekly_upper      yearly  \
# 1008           -533.175053  -6.439930     -6.439930     -6.439930 -526.735123
# 1009           -495.907742  17.514965     17.514965     17.514965 -513.422706
# 1010           -505.261890  -8.209973     -8.209973     -8.209973 -497.051917
# 1011           -478.771154  -1.629922     -1.629922     -1.629922 -477.141233
# 1012           -479.411834 -26.131510    -26.131510    -26.131510 -453.280324
#
#       yearly_lower  yearly_upper  multiplicative_terms  \
# 1008   -526.735123   -526.735123                   0.0
# 1009   -513.422706   -513.422706                   0.0
# 1010   -497.051917   -497.051917                   0.0
# 1011   -477.141233   -477.141233                   0.0
# 1012   -453.280324   -453.280324                   0.0
#
#       multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 1008                         0.0                         0.0  13420.739488
# 1009                         0.0                         0.0  13502.092498
# 1010                         0.0                         0.0  13536.824048
# 1011                         0.0                         0.0  13607.400482
# 1012                         0.0                         0.0  13650.845501

# %% [markdown]
# ### Plotting Values
# * Blue line = forecasted values
# * Black dots = observed values
# * Uncertainty intervals = blue shaded region

# %%
mod.plot(forecast, uncertainty=True)
plt.show()

# %% [markdown]
# #### Graph above zoomed in

# %%
mod.plot(forecast, uncertainty=True)

plt.xlim(['2019-04-01', '2019-10-10'])
plt.ylim([5000, 15000])
plt.show()

# %% [markdown]
# #### Plotted components of the forecasts

# %%
mod.plot_components(forecast)
plt.show()
