# %% [markdown]
# # Recurrent Neural Network - LSTM - Technical Indicators

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
plt.style.use("bmh")
import ta

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %% [markdown]
# ### Loading the Data

# %%
df = pd.read_csv("BTC-USD.csv")

# %% [markdown]
# #### Datetime Conversion

# %%
# Datetime conversion
df['Date'] = pd.to_datetime(df.Date)

# Setting the index
df.set_index('Date', inplace=True)

# Dropping any NaNs
df.dropna(inplace=True)

# %% [markdown]
# ## Preprocessing Data
# #### (adding technical indicators)

# %%
# Adding all the indicators
df = ta.add_all_ta_features(df, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)

# Dropping everything else besides 'Close' and the Indicators
df.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/ta/trend.py:543: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i]/self._trs[i])
# /anaconda3/lib/python3.7/site-packages/ta/trend.py:547: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i]/self._trs[i])

# %%
# Checking the new df with indicators
print(df.shape)

df.tail()
# Out:
# (1827, 69)
#                   Close    volume_adi    volume_obv  volume_cmf     volume_fi  \
# Date
# 2020-04-18  7257.665039  9.459779e+11  3.350679e+11    0.154987  2.301903e+12
# 2020-04-19  7189.424805  9.270127e+11  3.037567e+11    0.095078  1.667819e+12
# 2020-04-20  6881.958496  8.979297e+11  2.660096e+11    0.056118 -2.284357e+11
# 2020-04-21  6880.323242  8.952122e+11  2.334199e+11    0.000194 -2.034152e+11
# 2020-04-22  7117.207520  9.216083e+11  2.666690e+11    0.049381  9.508158e+11
#
#              volume_em  volume_sma_em    volume_vpt  volume_nvi  \
# Date
# 2020-04-18   39.455576      14.996960  6.441652e+08  401.811303
# 2020-04-19   16.012555      15.656176  4.439630e+08  398.033270
# 2020-04-20 -199.344021     -15.535207 -1.908715e+09  398.033270
# 2020-04-21  -47.121404     -30.889859 -1.622055e+09  397.938691
# 2020-04-22  102.309626     -22.518512  1.136999e+09  397.938691
#
#             volatility_atr  ...  momentum_uo  momentum_stoch  \
# Date                        ...
# 2020-04-18      309.267281  ...    58.305982       80.482855
# 2020-04-19      289.687281  ...    57.882463       72.661043
# 2020-04-20      301.197313  ...    48.274163       37.418728
# 2020-04-21      281.088519  ...    49.705534       40.565885
# 2020-04-22      280.788066  ...    58.250731       71.468608
#
#             momentum_stoch_signal  momentum_wr  momentum_ao  momentum_kama  \
# Date
# 2020-04-18              68.931229   -19.517145   414.660288    6832.238996
# 2020-04-19              71.705862   -27.338957   418.194977    6836.303899
# 2020-04-20              63.520875   -62.581272   414.824413    6836.535443
# 2020-04-21              50.215219   -59.434115   373.201492    6836.769982
# 2020-04-22              49.817740   -28.531392   316.830271    6840.775091
#
#             momentum_roc  others_dr  others_dlr    others_cr
# Date
# 2020-04-18     -0.194123   2.275596    2.250090  2969.273226
# 2020-04-19      0.181292  -0.940251   -0.944699  2940.414368
# 2020-04-20     -6.164904  -4.276647   -4.370789  2810.386583
# 2020-04-21     -5.775965  -0.023761   -0.023764  2809.695032
# 2020-04-22      3.666370   3.442924    3.384981  2909.873612
#
# [5 rows x 69 columns]

# %%
# Only using the last 1000 days of data to get a more accurate representation of the current climate
df = df.tail(1000)

# %% [markdown]
# ### Scaling

# %%
# Scale fitting the close prices separately for inverse_transformations purposes later
close_scaler = MinMaxScaler()

close_scaler.fit(df[['Close']])
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
# Normalizing/Scaling the Data
scaler = MinMaxScaler()
df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns, index=df.index)
# %%
def split_sequence(seq, n_steps_in, n_steps_out):
    """
    Splits the multivariate time sequence
    """
    
    # Creating a list for both variables
    X, y = [], []
    
    for i in range(len(seq)):
        
        # Finding the end of the current sequence
        end = i + n_steps_in
        out_end = end + n_steps_out
        
        # Breaking out of the loop if we have exceeded the dataset's length
        if out_end > len(seq):
            break
        
        # Splitting the sequences into: x = past prices and indicators, y = prices ahead
        seq_x, seq_y = seq[i:end, :], seq[end:out_end, 0]
        
        X.append(seq_x)
        y.append(seq_y)
    
    return np.array(X), np.array(y)

# %%
def visualize_training_results(results):
    """
    Plots the loss and accuracy for the training and testing data
    """
    history = results.history
    plt.figure(figsize=(14,5))
    plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'loss'])
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
    
    plt.figure(figsize=(14,5))
    plt.plot(history['val_accuracy'])
    plt.plot(history['accuracy'])
    plt.legend(['val_accuracy', 'accuracy'])
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
def layer_maker(n_layers, n_nodes, activation, drop=None, d_rate=.5):
    """
    Creates a specified number of hidden layers for an RNN
    Optional: Adds regularization option - the dropout layer to prevent potential overfitting (if necessary)
    """
    
    # Creating the specified number of hidden layers with the specified number of nodes
    for x in range(1,n_layers+1):
        model.add(LSTM(n_nodes, activation=activation, return_sequences=True))

        # Adds a Dropout layer after every Nth hidden layer (the 'drop' variable)
        try:
            if x % drop == 0:
                model.add(Dropout(d_rate))
        except:
            pass

# %% [markdown]
# ### Splitting the Data

# %%
# How many periods looking back to learn
n_per_in  = 30

# How many periods to predict
n_per_out = 10

# Features 
n_features = df.shape[1]

# Splitting the data into appropriate sequences
X, y = split_sequence(df.to_numpy(), n_per_in, n_per_out)

# %% [markdown]
# ## Modeling - LSTM (RNN)

# %% [markdown]
# ### Creating the Neural Network

# %%
# Instatiating the model
model = Sequential()

# Activation
activ = "softsign"

# Input layer
model.add(LSTM(30, activation=activ, return_sequences=True, input_shape=(n_per_in, n_features)))

# Hidden layers
layer_maker(n_layers=6, n_nodes=8, activation=activ)

# Final Hidden layer
model.add(LSTM(10, activation=activ))

# Output layer
model.add(Dense(n_per_out))

# Model summary
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_48 (LSTM)               (None, 30, 30)            12000
# _________________________________________________________________
# lstm_49 (LSTM)               (None, 30, 8)             1248
# _________________________________________________________________
# lstm_50 (LSTM)               (None, 30, 8)             544
# _________________________________________________________________
# lstm_51 (LSTM)               (None, 30, 8)             544
# _________________________________________________________________
# lstm_52 (LSTM)               (None, 30, 8)             544
# _________________________________________________________________
# lstm_53 (LSTM)               (None, 30, 8)             544
# _________________________________________________________________
# lstm_54 (LSTM)               (None, 30, 8)             544
# _________________________________________________________________
# lstm_55 (LSTM)               (None, 10)                760
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                110
# =================================================================
# Total params: 16,838
# Trainable params: 16,838
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the data with selected specifications
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %% [markdown]
# ### Fitting and Training the RNN

# %%
res = model.fit(X, y, epochs=20, batch_size=128, validation_split=0.1)
# Out:
# Train on 864 samples, validate on 97 samples
# Epoch 1/20
# 864/864 [==============================] - 4s 5ms/step - loss: 0.1099 - accuracy: 0.1030 - val_loss: 0.0982 - val_accuracy: 0.0928
# Epoch 2/20
# 864/864 [==============================] - 1s 976us/step - loss: 0.0985 - accuracy: 0.1065 - val_loss: 0.0851 - val_accuracy: 0.0928
# Epoch 3/20
# 864/864 [==============================] - 1s 957us/step - loss: 0.0867 - accuracy: 0.1065 - val_loss: 0.0713 - val_accuracy: 0.0928
# Epoch 4/20
# 864/864 [==============================] - 1s 817us/step - loss: 0.0751 - accuracy: 0.1065 - val_loss: 0.0579 - val_accuracy: 0.0928
# Epoch 5/20
# 864/864 [==============================] - 1s 873us/step - loss: 0.0640 - accuracy: 0.1065 - val_loss: 0.0456 - val_accuracy: 0.0928
# Epoch 6/20
# 864/864 [==============================] - 1s 909us/step - loss: 0.0547 - accuracy: 0.1065 - val_loss: 0.0354 - val_accuracy: 0.0928
# Epoch 7/20
# 864/864 [==============================] - 1s 972us/step - loss: 0.0473 - accuracy: 0.1065 - val_loss: 0.0280 - val_accuracy: 0.0928
# Epoch 8/20
# 864/864 [==============================] - 1s 894us/step - loss: 0.0412 - accuracy: 0.1262 - val_loss: 0.0228 - val_accuracy: 0.0928
# Epoch 9/20
# 864/864 [==============================] - 1s 864us/step - loss: 0.0347 - accuracy: 0.1725 - val_loss: 0.0205 - val_accuracy: 0.1237
# Epoch 10/20
# 864/864 [==============================] - 1s 896us/step - loss: 0.0283 - accuracy: 0.1701 - val_loss: 0.0202 - val_accuracy: 0.1134
# Epoch 11/20
# 864/864 [==============================] - 1s 964us/step - loss: 0.0242 - accuracy: 0.1481 - val_loss: 0.0181 - val_accuracy: 0.1134
# Epoch 12/20
# 864/864 [==============================] - 1s 993us/step - loss: 0.0202 - accuracy: 0.1690 - val_loss: 0.0151 - val_accuracy: 0.2062
# Epoch 13/20
# 864/864 [==============================] - 1s 959us/step - loss: 0.0174 - accuracy: 0.1794 - val_loss: 0.0165 - val_accuracy: 0.1959
# Epoch 14/20
# 864/864 [==============================] - 1s 981us/step - loss: 0.0149 - accuracy: 0.1713 - val_loss: 0.0155 - val_accuracy: 0.1959
# Epoch 15/20
# 864/864 [==============================] - 1s 931us/step - loss: 0.0129 - accuracy: 0.1597 - val_loss: 0.0168 - val_accuracy: 0.2062
# Epoch 16/20
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0113 - accuracy: 0.1296 - val_loss: 0.0157 - val_accuracy: 0.2062
# Epoch 17/20
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0098 - accuracy: 0.1181 - val_loss: 0.0180 - val_accuracy: 0.1959
# Epoch 18/20
# 864/864 [==============================] - 1s 991us/step - loss: 0.0086 - accuracy: 0.1088 - val_loss: 0.0200 - val_accuracy: 0.1443
# Epoch 19/20
# 864/864 [==============================] - 1s 981us/step - loss: 0.0075 - accuracy: 0.1146 - val_loss: 0.0168 - val_accuracy: 0.1031
# Epoch 20/20
# 864/864 [==============================] - 1s 930us/step - loss: 0.0064 - accuracy: 0.1204 - val_loss: 0.0163 - val_accuracy: 0.0928

# %% [markdown]
# ### Plotting the Accuracy and Loss

# %%
visualize_training_results(res)

# %% [markdown]
# ## Visualizing the Predictions

# %% [markdown]
# ### Validating the Model
# Plotting the difference between the Actual closing prices and the Predicted prices

# %%
# Transforming the actual values to their original price
actual = pd.DataFrame(close_scaler.inverse_transform(df[["Close"]]), 
                      index=df.index, 
                      columns=[df.columns[0]])

# Creating an empty DF to store the predictions
predictions = pd.DataFrame(index=df.index, columns=[df.columns[0]])

for i in range(n_per_in, len(df)-n_per_in, n_per_in):
    # Creating rolling intervals to predict off of
    x = df[-i - n_per_in:-i]

    # Predicting using rolling intervals
    yhat = model.predict(np.array(x).reshape(1, n_per_in, n_features))

    # Transforming values back to their normal prices
    yhat = close_scaler.inverse_transform(yhat)[0]

    # DF to store the values and append later
    pred_df = pd.DataFrame(yhat, 
                           index=pd.date_range(start=x.index[-1], 
                                               periods=len(yhat), 
                                               freq="D"),
                           columns=[x.columns[0]])

    # Updating the predictions DF
    predictions.update(pred_df)
    
# Plotting
plt.figure(figsize=(14,5))

# Plotting those predictions
plt.plot(predictions, label='Predicted')

# Plotting the actual values
plt.plot(actual, label='Actual')

plt.title(f"Predicted vs Actual Closing Prices")
plt.ylabel("Price")
plt.legend()
plt.xlim('2019-05', '2020-05')
plt.show()

# %% [markdown]
# ### Predicting/Forecasting the future prices

# %%
# Predicting off of y because it contains the most recent dates
yhat = model.predict(np.array(df.tail(n_per_in)).reshape(1, n_per_in, n_features))

# Transforming the predicted values back to their original prices
yhat = close_scaler.inverse_transform(yhat)[0]

# Creating a DF of the predicted prices
preds = pd.DataFrame(yhat, 
                     index=pd.date_range(start=df.index[-1], 
                                         periods=len(yhat), 
                                         freq="D"), 
                     columns=[df.columns[0]])

# Printing the predicted prices
print(preds)

# Number of periods back to visualize the actual values
pers = 11

# Transforming the actual values to their original price
actual = pd.DataFrame(close_scaler.inverse_transform(df[["Close"]].tail(pers)), 
                      index=df.Close.tail(pers).index, 
                      columns=[df.columns[0]]).append(preds.head(1))

# Plotting
plt.figure(figsize=(14,5))
plt.plot(actual, label="Actual Prices")
plt.plot(preds, label="Predicted Prices")
plt.ylabel("Price")
plt.xlabel("Dates")
plt.title(f"Forecasting the next {len(yhat)} days")
plt.legend()
plt.show()
# Out:
#                   Close
# 2020-04-22  6611.041992
# 2020-04-23  5651.129883
# 2020-04-24  6243.551270
# 2020-04-25  5306.021973
# 2020-04-26  7222.842285
# 2020-04-27  6618.437988
# 2020-04-28  7496.256348
# 2020-04-29  4724.532227
# 2020-04-30  6240.460449
# 2020-05-01  3196.938477
